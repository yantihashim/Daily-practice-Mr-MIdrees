# %%
print("Welcome Yanti!")

name = "Yanti"
print("Hello", name)
# Out:
# Welcome Yanti!
# Hello Yanti

# %%
# Exercise 1: Simple Math
price = 120
discount = 15
final_price = price - discount

print("Original price:", price)
print("Discount:", discount)
print("Final price:", final_price)
# Out:
# Original price: 120
# Discount: 15
# Final price: 105

# %%
# Exercise 2: Percentage Discount
price = 250
discount_percent = 20

discount_amount = price * (discount_percent / 100)
final_price = price - discount_amount

print("Price:", price)
print("Discount %:", discount_percent)
print("You save:", discount_amount)
print("Final price:", final_price)
# Out:
# Price: 250
# Discount %: 20
# You save: 50.0
# Final price: 200.0

# %%
# Exercise 3: List of items
items = ["apple", "banana", "grapes", "mango"]
print("Shopping list:")
for item in items:
    print("-", item)
# Out:
# Shopping list:
# - apple
# - banana
# - grapes
# - mango
