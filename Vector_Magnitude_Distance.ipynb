# %% [markdown]
# ### Vector Magnitude and Distance
#
# Goal:
# - Understand vector length using Pythagorean theorem
# - Apply algebra to vectors

# %%
# Vector OP where P = (10, 30)

x = 10
y = 30

# magnitude = sqrt(x^2 + y^2)
magnitude_OP = (x**2 + y**2) ** 0.5
magnitude_OP
